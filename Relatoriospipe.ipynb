# %%
import pandas as pd
import re
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-101-33f7ef90d4df> in <module>
#       1 import pandas as pd
#       2 import re
# ----> 3 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
df = pd.read_csv('deals2410452-48.csv')
df
# Out:
#     Negócio - Negócio criado em  \
# 0           2021-01-02 02:05:54
# 1           2021-01-02 17:39:10
# 2           2021-01-02 19:30:00
# 3           2021-01-03 14:53:19
# 4           2021-01-04 01:10:52
# ..                          ...
# 213         2021-03-26 14:56:40
# 214         2021-03-29 20:37:35
# 215         2021-03-30 20:17:36
# 216         2021-03-31 10:10:15
# 217         2021-03-31 15:07:19
#
#                                       Negócio - Título  Negócio - Valor  \
# 0         Glennie Koss - Zakary - 71404 Rogahn Circles              0.0
# 1            Paramax  - Adriana Fernandes  - Sao Paulo              0.0
# 2                        Brainwork - Celso - Sao Paulo              0.0
# 3      colabora direito - thais barcelos - porto alere            179.9
# 4         Leola Pfeffer - Norval - 47755 Damian Canyon              0.0
# ..                                                 ...              ...
# ...

# %%
pd.read_csv('deals-2410452-49.csv')
# Out:
#                                       Negócio - Título
# 0         Glennie Koss - Zakary - 71404 Rogahn Circles
# 1            Paramax  - Adriana Fernandes  - Sao Paulo
# 2                        Brainwork - Celso - Sao Paulo
# 3      colabora direito - thais barcelos - porto alere
# 4         Leola Pfeffer - Norval - 47755 Damian Canyon
# ..                                                 ...
# 373  Houzen Consultoria - Henrique Pizzatto - Curit...
# 374       SABRA Consultorios - Jaime Vogel - Santos Sp
# 375   nao tem nome ainda - Andre Maia Filho - salvador
# 376             Gexfin - Otton Junior - Rio de Janeiro
# 377         Sangha Platina Solaris - Frederico - BH/MG
#
# [378 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['Negócio - Negócio criado em', 'Negócio - Título', 'Negócio - Valor',
#        'Negócio - Etapa', 'Negócio - Data atualizada', 'Negócio - Organização',
#        'Negócio - Subdomínio', 'Negócio - Pessoa de contato',
#        'Negócio - Data de ganho', 'Negócio - Motivo da perda',
#        'Negócio - Atividades concluídas', 'Negócio - Atividades para fazer',
#        'Negócio - Data de perda', 'Negócio - Negócio fechado em',
#        'Negócio - Valor de produtos', 'Organização - Segmento',
#        'Organização - Situação do Espaço',
#        'Negócio - Data da Última Atividade', 'Organização - Prioridades',
#        'Organização - Dores/Expectativas',
#        'Negócio - Número de mensagens de e-mail',
#        'Organização - Negócios ganhos', 'Organização - Negócios perdidos',
#        'Organização - Capacidade do Espaço', 'Negócio - ID',
#        'Negócio - Quantidade de produtos',
#        'Negócio - Data finalização Implantação',
# ...

# %%
df2 = df[['Negócio - Título','Negócio - Data de ganho','Negócio - Motivo da perda','Negócio - Atividades concluídas','Organização - Segmento']]
df2
# Out:
#                                       Negócio - Título  \
# 0         Glennie Koss - Zakary - 71404 Rogahn Circles
# 1            Paramax  - Adriana Fernandes  - Sao Paulo
# 2                        Brainwork - Celso - Sao Paulo
# 3      colabora direito - thais barcelos - porto alere
# 4         Leola Pfeffer - Norval - 47755 Damian Canyon
# ..                                                 ...
# 213                 be social - Flow Digital - Curvelo
# 214  Jobclun coworking - Guilherme Sousa Batista - ...
# 215  Marcelo Moss - Marcelo Fabricio Alves Carlos -...
# 216                 BPartners - Fabio Fama - Sao Paulo
# 217         Conectados Coworking - Murilo - LondrinaPR
#
#     Negócio - Data de ganho        Negócio - Motivo da perda  \
# 0                       NaN                    Incomunicável
# 1                       NaN                              NaN
# 2                       NaN  Desistiu de montar um coworking
# ...

# %%
#Acre
ac = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="ac":
            ac.append(i)

for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="acre":
            ac.append(i)

# %%
#Alagoas
al = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="al":
            al.append(i)

for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="alagoas":
            al.append(i)

# %%
#Amapá
ap = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="ap":
            ap.append(i)

for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="amapa" or str(q).lower() =="amapá":
            ap.append(i)

# %%
#Amazonas
am = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="am":
            am.append(i)

for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="amazonas":
            am.append(i)

# %%
#Bahia
ba = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="ba":
            ba.append(i)

for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="bahia":
            ba.append(i)

# %%
#Ceará
ce = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="ce":
            ce.append(i)

for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="ceara" or str(q).lower() =="ceará":
            ce.append(i)

# %%
#Espírito Santo
es = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    num = 0
    for q in x:
        if str(q).lower() =="espírito" or str(q).lower() == "espirito":
            num = num+ 1
        elif str(q).lower() =="santo":
            num = num+ 1
    if num >=2:
        es.append(i)
        
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="es":
            es.append(i)

# %%
#Goiás
go = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="go":
            go.append(i)

for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="goias" or str(q).lower() =="goiás":
            go.append(i)

# %%
#Maranhão
ma = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="ma":
            ma.append(i)

for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="maranhao" or str(q).lower() =="maranhão":
            ma.append(i)

# %%
#Mato Grosso
mt = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    num = 0
    for q in x:
        if str(q).lower() =="mato":
            num = num+ 1
        elif str(q).lower() =="grosso":
            num = num+ 1
    if num >=2:
        mt.append(i)
        
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="mt":
            mt.append(i)

# %%
#Mato Grosso do Sul
ms = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    num = 0
    for q in x:
        if str(q).lower() =="mato":
            num = num+ 1
        elif str(q).lower() =="grosso":
            num = num+ 1
        elif str(q).lower() =="sul":
            num = num+ 1
    if num >=3:
        ms.append(i)
        
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="ms":
            ms.append(i)

# %%
#Minas Gerais
mg = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    num = 0
    for q in x:
        if str(q).lower() =="minas":
            num = num+ 1
        elif str(q).lower() =="gerais":
            num = num+ 1
    if num >=2:
        mg.append(i)
        
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="mg":
            mg.append(i)

# %%
#Pará
pa = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="pa":
            pa.append(i)

for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="para" or str(q).lower() =="pará":
            pa.append(i)

# %%
#Paraíba
pb = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="pb":
            pb.append(i)

for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="paraiba" or str(q).lower() =="paraíba":
            pb.append(i)

# %%
#Paraná
pr = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="pr":
            pr.append(i)

for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="parana" or str(q).lower() =="paraná":
            pr.append(i)

# %%
#Pernambuco
pe = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="pe":
            pe.append(i)

for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="pernambuco" :
            pe.append(i)

# %%
#Piauí
pi = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="pi":
            pi.append(i)

for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="piaui" or str(q).lower() =="piauí":
            pi.append(i)

# %%
#Rio de Janeiro
rj = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    num = 0
    for q in x:
        if str(q).lower() =="rio":
            num = num+ 1
        elif str(q).lower() =="janeiro":
            num = num+ 1
    if num >=2:
        rj.append(i)
        
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="rj":
            rj.append(i)

# %%
#Rio Grande do Norte
rn = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    num = 0
    for q in x:
        if str(q).lower() =="rio":
            num = num+ 1
        elif str(q).lower() =="grande":
            num = num+ 1
        elif str(q).lower() =="norte":
            num = num+ 1
    if num >=3:
        rn.append(i)
        
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="rn":
            rn.append(i)

# %%
#Rio Grande do Sul
rs = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    num = 0
    for q in x:
        if str(q).lower() =="rio":
            num = num+ 1
        elif str(q).lower() =="grande":
            num = num+ 1
        elif str(q).lower() =="sul":
            num = num+ 1
    if num >=3:
        rs.append(i)
        
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="rs":
            rs.append(i)

# %%
#Rondônia
ro = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="ro":
            ro.append(i)

for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="rondonia" or str(q).lower() =="rondônia":
            ro.append(i)

# %%
#Roraima
rr = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="rr":
            rr.append(i)

for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="roraima":
            rr.append(i)

# %%
#Santa Catarina
sc = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    num = 0
    for q in x:
        if str(q).lower() =="santa":
            num = num+ 1
        elif str(q).lower() =="catarina":
            num = num+ 1
    if num >=2:
        sc.append(i)
        
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="sc":
            sc.append(i)

# %%
#São Paulo
sp = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    num = 0
    for q in x:
        if str(q).lower() =="sao" or str(q).lower() == "são":
            num = num+ 1
        elif str(q).lower() =="paulo":
            num = num+ 1
    if num >=2:
        sp.append(i)
        
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="sp":
            sp.append(i)

# %%
#Sergipe
se = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="se":
            se.append(i)

for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="sergipe":
            se.append(i)

# %%
#Tocantins
to = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="to":
            to.append(i)

for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="tocantins":
            to.append(i)

# %%
#Distrito Federal
df = []
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    num = 0
    for q in x:
        if str(q).lower() =="distrito":
            num = num+ 1
        elif str(q).lower() =="federal":
            num = num+ 1
    if num >=2:
        df.append(i)
        
for i in df2['Negócio - Título']:
    data = i.replace(' ','-')
    x = re.split(',|_|-|!/', data) 
    for q in x:
        if str(q).lower() =="df":
            df.append(i)

# %%
len(rj)
# Out:
# 17
